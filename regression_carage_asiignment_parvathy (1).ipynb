# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("/content/car_age_price.csv")

# %%
data.head()
# Out:
#    Year   Price
# 0  2018  465000
# 1  2019  755000
# 2  2019  700000
# 3  2018  465000
# 4  2018  465000

# %%
data.shape
# Out:
# (112, 2)

# %%
data.isnull().sum()
# Out:
# Year     0
# Price    0
# dtype: int64

# %%
data.describe()
# Out:
#               Year          Price
# count   112.000000     112.000000
# mean   2016.669643  483866.044643
# std       1.629616   91217.450533
# min    2013.000000  300000.000000
# 25%    2015.000000  423750.000000
# 50%    2017.000000  500000.000000
# 75%    2017.000000  550000.000000
# max    2020.000000  755000.000000

# %%
data.duplicated().sum()     #counting duplicates if any
# Out:
# 54

# %%
d = data[data.duplicated()]
d
# Out:
#      Year   Price
# 3    2018  465000
# 4    2018  465000
# 9    2017  575000
# 15   2017  500000
# 16   2017  500000
# 18   2019  500000
# 19   2017  500000
# 20   2018  500000
# 21   2019  500000
# 23   2017  550000
# 24   2017  550000
# 25   2017  550000
# 26   2017  550000
# 27   2017  550000
# 28   2017  550000
# 29   2017  550000
# 31   2017  550000
# 32   2017  550000
# 33   2017  550000
# 35   2017  550000
# 36   2017  550000
# 41   2019  600000
# 44   2019  550000
# 46   2019  500000
# 47   2018  450000
# 51   2018  550000
# 53   2013  345000
# 55   2017  550000
# 57   2017  550000
# 62   2017  540000
# 64   2015  490000
# 66   2017  525000
# 72   2015  300000
# 74   2017  490000
# 75   2017  490000
# 76   2015  450000
# 79   2015  400000
# 82   2015  390000
# 84   2015  325000
# 87   2017  520000
# 88   2017  520000
# 89   2017  520000
# 90   2017  520000
# 91   2017  520000
# 92   2017  520000
# 93   2017  520000
# 94   2017  520000
# 95   2017  520000
# 96   2017  520000
# 101  2015  400000
# 102  2015  350000
# 105  2014  400000
# 106  2015  300000
# 111  2015  425000

# %%
data.drop_duplicates(inplace=True)    #Droping duplicate values

# %%
data.duplicated().sum()      #Checking for duplicates again
# Out:
# 0

# %%
data["Year"].value_counts()
# Out:
# 2017    15
# 2015    12
# 2019     7
# 2018     6
# 2016     6
# 2014     5
# 2020     4
# 2013     3
# Name: Year, dtype: int64

# %%
# Outlier Analysis
#fig ,axs= plt.subplots(1, figsize = (5,5))
#plt1 = sns.boxplot(x=data['Year'],color='r')
#plt1.show()

# %%
plt.figure(figsize=(5, 7))
sns.boxplot(x=data['Year'],color='r')
plt.show()

# %%
#finding the  linear relationship using  perarsons

x_simple = data['Year']
y_simple = data['Price']
my_rho = np.corrcoef(x_simple, y_simple)

print(my_rho)
# Out:
# [[1.         0.80727554]
#  [0.80727554 1.        ]]

# %% [markdown]
# Positive pearsons corelation.The ones on the diagonals, indicating that the correlation coefficient of a variable with itself is one
#
#  If random variables have high linear associations then their correlation coefficient is close to +1 or -1.

# %%
#define data
x = data['Year']
y = data['Price']

#find line of best fit
a, b = np.polyfit(x, y, 1)

#add points to plot
plt.scatter(x, y, color='red')

#add line of best fit to plot
plt.plot(x, a*x+b, color='steelblue', linestyle='--', linewidth=2)

# %%
import plotly.express as px
figure = px.scatter(data_frame = data,

                    x="Year",
                    y="Price",

                    trendline="ols",
                    title = "Relationship Between Year and price")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5b46e9e4-b062-4327-b4e5-78f12911dc92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b46e9e4-b062-4327-b4e5-78f12911dc92")) {                    Plotly.newPlot(                        "5b46e9e4-b062-4327-b4e5-78f12911dc92",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[2018,2019,2019,2015,2016,2017,2017,2019,2018,2017,2019,2017,2017,2015,2019,2017,2017,2018,2020,2019,2018,2019,2018,2016,2018,2013,2013,2017,2014,2014,2016,2015,2017,2017,2017,2015,2015,2015,2015,2017,2013,2015,2015,2015,2014,2017,2015,2017,2020,2020,2020,2016,2017,2014,2016,2014,2015,2016],"xaxis":"x","y":[465000,755000,700000,350000,425000,575000,509999,500000,500000,500000,600000,475000,550000,434999,650000,450000,486000,475000,545000,525000,550000,550000,450000,396000,600000,325000,345000,525000,341000,450000,550000,490000,540000,595000,495000,400000,465000,300000,450000,490000,320000,325000,409999,390000,390000,480000,320000,520000,640000,700000,600000,350000,375000,400000,375000,300000,425000,420000],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003ePrice = 44986.1 * Year + -9.0243e+07\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.651694\u003cbr\u003e\u003cbr\u003eYear=%{x}\u003cbr\u003ePrice=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[2013,2013,2013,2014,2014,2014,2014,2014,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2016,2016,2016,2016,2016,2016,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2018,2018,2018,2018,2018,2018,2019,2019,2019,2019,2019,2019,2019,2020,2020,2020,2020],"xaxis":"x","y":[313894.5590669811,313894.5590669811,313894.5590669811,358880.61014966667,358880.61014966667,358880.61014966667,358880.61014966667,358880.61014966667,403866.66123235226,403866.66123235226,403866.66123235226,403866.66123235226,403866.66123235226,403866.66123235226,403866.66123235226,403866.66123235226,403866.66123235226,403866.66123235226,403866.66123235226,403866.66123235226,448852.71231503785,448852.71231503785,448852.71231503785,448852.71231503785,448852.71231503785,448852.71231503785,493838.76339772344,493838.76339772344,493838.76339772344,493838.76339772344,493838.76339772344,493838.76339772344,493838.76339772344,493838.76339772344,493838.76339772344,493838.76339772344,493838.76339772344,493838.76339772344,493838.76339772344,493838.76339772344,493838.76339772344,538824.814480409,538824.814480409,538824.814480409,538824.814480409,538824.814480409,538824.814480409,583810.8655630946,583810.8655630946,583810.8655630946,583810.8655630946,583810.8655630946,583810.8655630946,583810.8655630946,628796.9166457802,628796.9166457802,628796.9166457802,628796.9166457802],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"] ...

# %%
X = data.drop('Price',axis=1)

# %%
X
# Out:
#      Year
# 0    2018
# 1    2019
# 2    2019
# 5    2015
# 6    2016
# 7    2017
# 8    2017
# 10   2019
# 11   2018
# 12   2017
# 13   2019
# 14   2017
# 17   2017
# 22   2015
# 30   2019
# 34   2017
# 37   2017
# 38   2018
# 39   2020
# 40   2019
# 42   2018
# 43   2019
# 45   2018
# 48   2016
# 49   2018
# 50   2013
# 52   2013
# 54   2017
# 56   2014
# 58   2014
# 59   2016
# 60   2015
# 61   2017
# 63   2017
# 65   2017
# 67   2015
# 68   2015
# 69   2015
# 70   2015
# 71   2017
# 73   2013
# 77   2015
# 78   2015
# 80   2015
# 81   2014
# 83   2017
# 85   2015
# 86   2017
# 97   2020
# 98   2020
# 99   2020
# 100  2016
# 103  2017
# 104  2014
# 107  2016
# 108  2014
# 109  2015
# 110  2016

# %%
y = data['Price']
y
# Out:
# 0      465000
# 1      755000
# 2      700000
# 5      350000
# 6      425000
# 7      575000
# 8      509999
# 10     500000
# 11     500000
# 12     500000
# 13     600000
# 14     475000
# 17     550000
# 22     434999
# 30     650000
# 34     450000
# 37     486000
# 38     475000
# 39     545000
# 40     525000
# 42     550000
# 43     550000
# 45     450000
# 48     396000
# 49     600000
# 50     325000
# 52     345000
# 54     525000
# 56     341000
# 58     450000
# 59     550000
# 60     490000
# 61     540000
# 63     595000
# 65     495000
# 67     400000
# 68     465000
# 69     300000
# 70     450000
# 71     490000
# 73     320000
# 77     325000
# 78     409999
# 80     390000
# 81     390000
# 83     480000
# 85     320000
# 86     520000
# 97     640000
# 98     700000
# 99     600000
# 100    350000
# 103    375000
# 104    400000
# 107    375000
# 108    300000
# 109    425000
# 110    420000
# Name: Price, dtype: int64

# %% [markdown]
# # **Splitting data into train and test**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,train_size=0.7,test_size=0.3,random_state=1)

# %%
X_train.head()
# Out:
#      Year
# 107  2016
# 59   2016
# 77   2015
# 86   2017
# 54   2017

# %%
y_train.head()
# Out:
# 107    375000
# 59     550000
# 77     325000
# 86     520000
# 54     525000
# Name: Price, dtype: int64

# %% [markdown]
# # **Building a Linear Model**

# %%
from sklearn.linear_model import LinearRegression
from sklearn import model_selection

# %%
lm=LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_,lm.coef_)
# Out:
# -89876937.91108131 [44804.31322609]

# %% [markdown]
# **Manualy calculating and predicting on year 2022**

# %%
(44804.31322609*2022)+-89876937.91108131
# Out:
# 717383.4320726693

# %%
x_new=pd.DataFrame({'Year':[2022]})

# %% [markdown]
# **Model prediction**

# %%
new_preds=lm.predict(x_new)
new_preds
# Out:
# array([717383.43208222])

# %% [markdown]
# We get the same prediction equivalent to manual calc.

# %% [markdown]
# **Predicting on test data**

# %%
preds=lm.predict(X_test)
preds
# Out:
# array([627774.80563003, 582970.49240394, 403753.23949955, 403753.23949955,
#        493361.86595175, 493361.86595175, 403753.23949955, 582970.49240394,
#        582970.49240394, 448557.55272564, 358948.92627347, 403753.23949955,
#        403753.23949955, 314144.61304736, 538166.17917784, 582970.49240394,
#        627774.80563003, 314144.61304736])

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
print('mean squared error',(mean_squared_error(y_test,preds)))

print('Root mean Squared Error',sqrt(mean_squared_error(y_test,preds)))
# Out:
# mean squared error 2814665301.245618
# Root mean Squared Error 53053.41931719027

# %% [markdown]
# # **Lasso Regression model**

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=0.1)
lasso.fit(X_train,y_train)
preds=lasso.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
print('Mean Squared Error',(mean_squared_error(y_test,preds)))
print('Root mean Squared Error',sqrt(mean_squared_error(y_test,preds)))
# Out:
# Mean Squared Error 2814665451.851859
# Root mean Squared Error 53053.420736573236

# %% [markdown]
# There is minute difference in lasso and linear regression.compared to linear lasso is better.
